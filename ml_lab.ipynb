# %% [markdown]
# <a href="https://www.kaggle.com/code/shivabairy/notebook3c8a426f4d?scriptVersionId=254184418" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
file_path = '/kaggle/input/indian-food-101/indian_food.csv'
columns_name = ['name','ingredients','diet','prep_time','cook_time','flavor_profile','course','state','region']
df = pd.read_csv(file_path,header=None,names=columns_name)
display(df.head())
# Out:
#              name                                        ingredients  \
# 0            name                                        ingredients
# 1      Balu shahi                    Maida flour, yogurt, oil, sugar
# 2          Boondi                            Gram flour, ghee, sugar
# 3  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 4          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
#
#          diet  prep_time  cook_time  flavor_profile   course        state  \
# 0        diet  prep_time  cook_time  flavor_profile   course        state
# 1  vegetarian         45         25           sweet  dessert  West Bengal
# 2  vegetarian         80         30           sweet  dessert    Rajasthan
# 3  vegetarian         15         60           sweet  dessert       Punjab
# 4  vegetarian         15         30           sweet  dessert    Rajasthan
#
#    region
# 0  region
# 1    East
# 2    West
# 3   North
# 4    West

# %%
df.replace("?", pd.NA, inplace=True)
df.dropna(inplace=True)
print(df.head())
# Out:
#              name                                        ingredients  \
# 0            name                                        ingredients
# 1      Balu shahi                    Maida flour, yogurt, oil, sugar
# 2          Boondi                            Gram flour, ghee, sugar
# 3  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 4          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
#
#          diet  prep_time  cook_time  flavor_profile   course        state  \
# 0        diet  prep_time  cook_time  flavor_profile   course        state
# 1  vegetarian         45         25           sweet  dessert  West Bengal
# 2  vegetarian         80         30           sweet  dessert    Rajasthan
# 3  vegetarian         15         60           sweet  dessert       Punjab
# 4  vegetarian         15         30           sweet  dessert    Rajasthan
#
#    region
# 0  region
# 1    East
# 2    West
# 3   North
# 4    West

# %%
[col for col in df.columns if df[col].isnull().sum() > 0]
# Out:
# []

# %%
x_train , x_test , y_train , y_test = train_test_split (df.drop(labels = ['prep_time'], axis=1), df['prep_time'],test_size = 0.3, random_state = 0)

constant_feature = [ features for features in x_train.columns if x_train[features].nunique() == 1]
len(constant_feature)
# Out:
# 0

# %%
quasi_constant_feature = []

for features in x_train.columns:
    predominant = (x_train[features].value_counts() / float(len(x_train))).sort_values(ascending=False).values[0]

    if predominant > 0.999:
        quasi_constant_feature.append(feature)

len(quasi_constant_feature)
# Out:
# 0

# %%
duplicated_feature = []

for i in range(len(x_train.columns)):
    col_1 = x_train.columns[i]

    for col_2 in x_train.columns[i + 1:]:
        if x_train[col_1].equals(x_train[col_2]):
            duplicated_feature.append(col_2)

duplicated_features = set(duplicated_feature)
print(len(duplicated_features))
# Out:
# 0

# %%
filepath2 = "/kaggle/input/2020-usa-election-vote-percentages-by-state/democratic_vs_republican_votes_by_usa_state_2020.csv"
columns2 = ['state' , 'votes' , 'electoral_vote' , 'usa_state' , 'usa_state_code']
df2 = pd.read_csv(filepath2,names=columns2)
display(df2.head())
# Out:
#             state    votes electoral_vote       usa_state     usa_state_code
# state         DEM      REP      usa_state  usa_state_code   percent_democrat
# Alabama    843473  1434159        Alabama              AL  37.03289205631111
# Alaska      45758    80999         Alaska              AK  36.09899256056865
# Arizona   1643664  1626679        Arizona              AZ  50.25968224128172
# Arkansas   420985   761251       Arkansas              AR  35.60921846399535

# %%
df2.replace("?", pd.NA, inplace=True)
df2.dropna(inplace=True)
print(df2.head())
# Out:
#             state    votes electoral_vote       usa_state     usa_state_code
# state         DEM      REP      usa_state  usa_state_code   percent_democrat
# Alabama    843473  1434159        Alabama              AL  37.03289205631111
# Alaska      45758    80999         Alaska              AK  36.09899256056865
# Arizona   1643664  1626679        Arizona              AZ  50.25968224128172
# Arkansas   420985   761251       Arkansas              AR  35.60921846399535

# %%
[col for col in df2.columns if df2[col].isnull().sum() > 0]
# Out:
# []

# %%
x_train , x_test , y_train , y_test = train_test_split (df2.drop(labels = ['electoral_vote'], axis=1), df2['electoral_vote'],test_size = 0.3, random_state = 0)

constant_feature = [ features for features in x_train.columns if x_train[features].nunique() == 1]
len(constant_feature)
# Out:
# 0

# %%
quasi_constant_feature = []

for features in x_train.columns:
    predominant = (x_train[features].value_counts() / float(len(x_train))).sort_values(ascending=False).values[0]

    if predominant > 0.999:
        quasi_constant_feature.append(feature)

len(quasi_constant_feature)
# Out:
# 0

# %%
duplicated_feature = []

for i in range(len(x_train.columns)):
    col_1 = x_train.columns[i]

    for col_2 in x_train.columns[i + 1:]:
        if x_train[col_1].equals(x_train[col_2]):
            duplicated_feature.append(col_2)

duplicated_features = set(duplicated_feature)
print(len(duplicated_features))
# Out:
# 0
